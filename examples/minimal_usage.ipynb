# %%
import math
from randmut import randmut

# %%
def fun(x):
    return sum([math.sin(v) for v in x])

# %%
#minimizing the sum of three sinuses from -pi to pi
(x, f, _) = randmut(fun, 3 * [(-math.pi, math.pi)])
print("Minimal value found:", f)
print("With parameters:", x)
# Out:
# Starting random mutations...
# Iter. |   Time  |    F.Evals    |        Result        |  Stall  | Progress
#   1   |    0s   |      550      | -2.848353783582776   |   0/10  | ##################
#   2   |    0s   |      1100     | -2.95962469536702    |   0/10  | ##################
#   3   |    0s   |      1650     | -2.960506120323306   |   0/10  | ##################
#   4   |    0s   |      2200     | -2.9753298314125547  |   0/10  | ##################
#   5   |    0s   |      2750     | -2.983274537257564   |   0/10  | ##################
#   6   |    0s   |      3300     | -2.9844070803319096  |   0/10  | ##################
#   7   |    0s   |      3850     | -2.987858280265749   |   0/10  | ##################
#   8   |    0s   |      4400     | -2.987858280265749   |   1/10  | ##################
#   9   |    0s   |      4950     | -2.9949361475873255  |   0/10  | ##################
#   10  |    0s   |      5500     | -2.9968279481767017  |   0/10  | ##################
#   11  |    0s   |      6050     | -2.9984825226884633  |   0/10  | ##################
#   12  |    0s   |      6600     | -2.9987710607971043  |   0/10  | ##################
#   13  |    0s   |      7150     | -2.9993738361582976  |   0/10  | ##################
#   14  |    0s   |      7700     | -2.9993738361582976  |   1/10  | ##################
#   15  |    0s   |      8250     | -2.9996524030761336  |   0/10  | ##################
#   16  |    0s   |      8800     | -2.999652435946186   |   1/10  | ##################
#   17  |    0s   |      9350     | -2.999769824631103   |   0/10  | ##################
#   18  |    0s   |      9900     | -2.999769824631103   |   1/10  | ##################
#   19  |    0s   |     10450     | -2.999772593386747   |   0/10  | ##################
#   20  |    0s   |     11000     | -2.9997736904344388  |   0/10  | ##################
#   21  |    0s   |     11550     | -2.9998919240994875  |   0/10  | ##################
#   22  |    0s   |     12100     | -2.999903160186311   |   0/10  | ##################
#   23  |    0s   |     12650     | -2.9999043331905932  |   0/10  | ##################
#   24  |    0s   |     13200     | -2.9999113088126492  |   0/10  | ##################
#   25  |    0s   |     13750     | -2.9999113238561046  |   1/10  | ##################
#   26  |    0s   |     14300     | -2.9999113238561046  |   2/10  | ##################
#   27  |    0s   |     14850     | -2.99992338853984    |   0/10  | ##################
#   28  |    0s   |     15400     | -2.9999450530187937  |   0/10  | ##################
#   29  |    0s   |     15950     | -2.9999455737693124  |   1/10  | ##################
#   30  |    0s   |     16500     | -2.9999985771386415  |   0/10  | ##################
#   31  |    0s   |     17050     | -2.999998579890385   |   1/10  | ##################
#   32  |    0s   |     17600     | -2.9999985799404856  |   2/10  | ##################
#   33  |    0s   |     18150     | -2.999998582839497   |   3/10  | ##################
#   34  |    0s   |     18700     | -2.999998582839497   |   4/10  | ##################
#   35  |    0s   |     19250     | -2.9999985846582624  |   5/10  | ##################
#   36  |    0s   |     19800     | -2.999999818860221   |   0/10  | ##################
#   37  |    0s   |     20350     | -2.999999818888729   |   1/10  | ##################
#   38  |    0s   |     20900     | -2.999999818888917   |   2/10  | ##################
#   39  |    0s   |     21450     | -2.999999818888995   |   3/10  | ##################
#   40  |    0s   |     22000     | -2.9999998212458174  |   4/10  | ##################
#   41  |    0s   |     22550     | -2.9999998212458174  |   5/10  | ##################
#   42  |    0s   |     23100     | -2.9999998212458174  |   6/10  | ##################
#   43  |    0s   |     23650     | -2.999999970699748   |   7/10  | ##################
#   44  |    0s   |     24200     | -2.999999984670376   |   8/10  | ##################
#   45  |    0s   |     24750     | -2.999999991419193   |   9/10  | ##################
#   46  |    0s   |     25300     | -2.999999991419193   |  10/10  | ##################
#
# Minimal value found: -2.999999991419193
# With parameters: [-1.57086207 -1.57085714 -1.57070072]

# %%
#doing the same silently
(x, f, _) = randmut(fun, 3 * [(-math.pi, math.pi)], disp=False)
print("Minimal value found:", f)
print("With parameters:", x)
# Out:
# Minimal value found: -2.9999996540111833
# With parameters: [-1.57071682 -1.57026227 -1.57142913]
